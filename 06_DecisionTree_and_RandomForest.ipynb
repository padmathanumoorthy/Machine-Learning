# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('diabetes.csv')
data
# Out:
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0       1354778            0            171                      80
# 1       1147438            8             92                      93
# 2       1640031            7            115                      47
# 3       1883350            9            103                      78
# 4       1424119            1             85                      59
# ...         ...          ...            ...                     ...
# 9995    1469198            6             95                      85
# 9996    1432736            0             55                      51
# 9997    1410962            5             99                      59
# 9998    1958653            0            145                      67
# 9999    1332938           10            100                      54
#
#       TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# 0                   34            23  43.509726          1.213191   21
# 1                   47            36  21.240576          0.158365   23
# 2                   52            35  41.511523          0.079019   23
# 3                   25           304  29.582192          1.282870   43
# 4                   27            35  42.604536          0.549542   22
# ...                ...           ...        ...               ...  ...
# 9995                37           267  18.497542          0.660240   31
# 9996                 7            50  21.865341          0.086589   34
# 9997                47            67  30.774018          2.301594   43
# 9998                30            21  18.811861          0.789572   26
# 9999                34            27  38.840943          0.175465   23
#
#       Diabetic
# 0            0
# 1            0
# 2            0
# 3            1
# 4            0
# ...        ...
# 9995         0
# 9996         0
# 9997         1
# 9998         0
# 9999         0
#
# [10000 rows x 10 columns]

# %%
data.describe()
# Out:
#        PlasmaGlucose  DiastolicBloodPressure  ...  DiabetesPedigree           Age
# count   10000.000000            10000.000000  ...      10000.000000  10000.000000
# mean      107.850200               71.207500  ...          0.400944     30.134100
# std        31.920909               16.801478  ...          0.381463     12.106047
# min        44.000000               24.000000  ...          0.078044     21.000000
# 25%        84.000000               58.000000  ...          0.137065     22.000000
# 50%       105.000000               72.000000  ...          0.199698     24.000000
# 75%       129.000000               85.000000  ...          0.621158     35.000000
# max       192.000000              117.000000  ...          2.301594     77.000000
#
# [8 rows x 7 columns]

# %%
row_count = len(data)
print(f'Analysing {row_count} rows of data')

diabetic_count = data['Diabetic'].value_counts()
print(f'Diabetic count: {diabetic_count}')
# Out:
# Analysing 10000 rows of data
# Diabetic count: Diabetic
# 0    6656
# 1    3344
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.gca()
diabetic_count.plot.bar(ax=ax)
ax.set_title('Patients with diabetes')
ax.set_xlabel('Diagnosis')
ax.set_ylabel('Patient count')
plt.show()
fig.savefig('Diabetic.png')
plt.close(fig)
print('Figure saved')

# %%
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
import sklearn
sklearn.__version__
# Out:
# '1.6.1'

# %%
data
# Out:
#       PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0       1354778            0            171                      80
# 1       1147438            8             92                      93
# 2       1640031            7            115                      47
# 3       1883350            9            103                      78
# 4       1424119            1             85                      59
# ...         ...          ...            ...                     ...
# 9995    1469198            6             95                      85
# 9996    1432736            0             55                      51
# 9997    1410962            5             99                      59
# 9998    1958653            0            145                      67
# 9999    1332938           10            100                      54
#
#       TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  \
# 0                   34            23  43.509726          1.213191   21
# 1                   47            36  21.240576          0.158365   23
# 2                   52            35  41.511523          0.079019   23
# 3                   25           304  29.582192          1.282870   43
# 4                   27            35  42.604536          0.549542   22
# ...                ...           ...        ...               ...  ...
# 9995                37           267  18.497542          0.660240   31
# 9996                 7            50  21.865341          0.086589   34
# 9997                47            67  30.774018          2.301594   43
# 9998                30            21  18.811861          0.789572   26
# 9999                34            27  38.840943          0.175465   23
#
#       Diabetic
# 0            0
# 1            0
# 2            0
# 3            1
# 4            0
# ...        ...
# 9995         0
# 9996         0
# 9997         1
# 9998         0
# 9999         0
#
# [10000 rows x 10 columns]

# %%
data.columns
# Out:
# Index(['PatientID', 'Pregnancies', 'PlasmaGlucose', 'DiastolicBloodPressure',
#        'TricepsThickness', 'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age',
#        'Diabetic'],
#       dtype='object')

# %% [markdown]
# #### Separate features from the label

# %%
X, y = data[['PlasmaGlucose', 'DiastolicBloodPressure', 'TricepsThickness', 'SerumInsulin', 'BMI', 
            'DiabetesPedigree', 'Age']].values, data['Diabetic'].values

# %%
len(X)
# Out:
# 10000

# %%
len(y)
# Out:
# 10000

# %% [markdown]
# #### Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

print(len(X_train))
print(len(X_test))
# Out:
# 7000
# 3000

# %% [markdown]
# #### Train the Model

# %%
# %time
dtree_model = DecisionTreeClassifier()
dtree_model.fit(X_train, y_train) # Training
dtree_model
# Out:
# CPU times: user 19 μs, sys: 3 μs, total: 22 μs
# Wall time: 37.4 μs
# DecisionTreeClassifier()

# %%
predictions = dtree_model.predict(X_test)

# %%
acc = np.average(predictions == y_test)
acc
# Out:
# 0.8526666666666667

# %%
print(confusion_matrix(predictions, y_test))
# Out:
# [[1748  216]
#  [ 226  810]]

# %%
print(classification_report(predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      1964
#            1       0.79      0.78      0.79      1036
#
#     accuracy                           0.85      3000
#    macro avg       0.84      0.84      0.84      3000
# weighted avg       0.85      0.85      0.85      3000

# %%
X_new = [[120,83,27,195,37.89166881,0.865807302,22],
         [90,62,54,593,20.49619978,0.548990862,21]]

predictions = dtree_model.predict(X_new)

classnames = ['Non-Diabetic', 'Diabetic']

for prediction in predictions:
    print(classnames[prediction])
# Out:
# Non-Diabetic
# Diabetic

# %% [markdown]
# #### Visualize the Tree
# 1. Install Graphviz software (https://graphviz.org/)
# 2. Install pydot (pip install pydot)
# 3. import the packages

# %%
# !pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-3.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyparsing>=3.0.9 in /home/coder/miniconda3/lib/python3.11/site-packages (from pydot) (3.2.1)
# Downloading pydot-3.0.4-py3-none-any.whl (35 kB)
# Installing collected packages: pydot
# Successfully installed pydot-3.0.4

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydot

# %%
# Out:
# array([[1.71000000e+02, 8.00000000e+01, 3.40000000e+01, ...,
#         4.35097259e+01, 1.21319135e+00, 2.10000000e+01],
#        [9.20000000e+01, 9.30000000e+01, 4.70000000e+01, ...,
#         2.12405757e+01, 1.58364981e-01, 2.30000000e+01],
#        [1.15000000e+02, 4.70000000e+01, 5.20000000e+01, ...,
#         4.15115235e+01, 7.90185680e-02, 2.30000000e+01],
#        ...,
#        [9.90000000e+01, 5.90000000e+01, 4.70000000e+01, ...,
#         3.07740178e+01, 2.30159419e+00, 4.30000000e+01],
#        [1.45000000e+02, 6.70000000e+01, 3.00000000e+01, ...,
#         1.88118606e+01, 7.89572255e-01, 2.60000000e+01],
#        [1.00000000e+02, 5.40000000e+01, 3.40000000e+01, ...,
#         3.88409428e+01, 1.75464759e-01, 2.30000000e+01]])

# %%
data
# Out:
#       PatientID  Pregnancies  PlasmaGlucose  ...  DiabetesPedigree  Age  Diabetic
# 0       1354778            0            171  ...          1.213191   21         0
# 1       1147438            8             92  ...          0.158365   23         0
# 2       1640031            7            115  ...          0.079019   23         0
# 3       1883350            9            103  ...          1.282870   43         1
# 4       1424119            1             85  ...          0.549542   22         0
# ...         ...          ...            ...  ...               ...  ...       ...
# 9995    1469198            6             95  ...          0.660240   31         0
# 9996    1432736            0             55  ...          0.086589   34         0
# 9997    1410962            5             99  ...          2.301594   43         1
# 9998    1958653            0            145  ...          0.789572   26         0
# 9999    1332938           10            100  ...          0.175465   23         0
#
# [10000 rows x 10 columns]

# %%
data.drop(['PatientID', 'Pregnancies', 'Diabetic'], axis=1, inplace=True)
features = data.columns
features
# Out:
# Index(['PlasmaGlucose', 'DiastolicBloodPressure', 'TricepsThickness',
#        'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age'],
#       dtype='object')

# %%
dot_data = StringIO()
export_graphviz(dtree_model, out_file=dot_data, feature_names=features, rounded=True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())

# %%
Image(graph[0].create_png())

# %% [markdown]
# #### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# %time
randomtree_model = RandomForestClassifier(n_estimators=100)
randomtree_model.fit(X_train, y_train)
randomtree_model
# Out:
# CPU times: user 5 μs, sys: 0 ns, total: 5 μs
# Wall time: 9.78 μs
# RandomForestClassifier()

# %%
predictions = randomtree_model.predict(X_test)
acc = np.average(predictions == y_test)
acc
# Out:
# 0.8946666666666667

# %%
print(confusion_matrix(predictions, y_test))
# Out:
# [[1846  168]
#  [ 128  858]]

# %%
print(classification_report(predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93      2014
#            1       0.84      0.87      0.85       986
#
#     accuracy                           0.90      3000
#    macro avg       0.89      0.89      0.89      3000
# weighted avg       0.90      0.90      0.90      3000

# %%
data.drop(['PatientID', 'Pregnancies', 'Diabetic'], axis=1, inplace=True)
features = data.columns
features
# Out:
# Index(['PlasmaGlucose', 'DiastolicBloodPressure', 'TricepsThickness',
#        'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age'],
#       dtype='object')

# %%
dot_data = StringIO()
export_graphviz(randomtree_model.estimators_[0], out_file=dot_data, feature_names=features, rounded=True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())

# %%
Image(graph[0].create_png())

# %%
len(randomtree_model.estimators_)
# Out:
# 200
